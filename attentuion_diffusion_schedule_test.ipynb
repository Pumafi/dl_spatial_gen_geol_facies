# %% [markdown]
# <a href="https://colab.research.google.com/github/Pumafi/dl_spatial_gen_geol_facies/blob/main/attentuion_diffusion_schedule_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
RUNNING_IN_COLAB = True

if RUNNING_IN_COLAB:
    # Uses a private Auth Token, giving read and write access to repo
    # TO DELETE IF REPO GOES PUBLIC
    REPO_URL = 'https://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@github.com/Pumafi/flumy-wgan-mines'
    BRANCH   = 'main'
    REPO_DIR = 'flumy-wgan-mines'

    from pathlib import Path

    # %cd /content

    if Path(REPO_DIR).is_dir():
      # !rm -rf {REPO_DIR}

    # Download the repository
    if not Path(REPO_DIR).is_dir():
        # !git clone --branch {BRANCH} --depth=1 -- {REPO_URL} {REPO_DIR}
    
    # %cd {REPO_DIR}
# Out:
# /content
# Cloning into 'flumy-wgan-mines'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 146 (delta 31), reused 74 (delta 8), pack-reused 0
# Receiving objects: 100% (146/146), 140.19 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Updating files: 100% (121/121), done.
# /content/flumy-wgan-mines

# %%
# !python3 -m pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.9/dist-packages (0.20.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (23.1)

# %%
import numpy as np
from data.load_data import load_data
from utils.visualisation import get_color_map

import math
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from keras import layers

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from keras import layers

import matplotlib.pyplot as plt
import numpy as np
import math

# %%
import functools

@tf.function
def marginal_prob_std(t, sigma):
  """Compute the standard deviation of p(xt|x0)

  Args:    
    t: A vector of time steps.
    sigma: The  in our SDE.  
  
  Returns:
    The standard deviation.
  """    
  return tf.math.sqrt((sigma**(2 * t) - 1.) / 2. / tf.math.log(sigma))

@tf.function
def diffusion_coeff(t, sigma=25.):
  """Compute the diffusion coefficient of our SDE.

  Args:
    t: A vector of time steps.
    sigma: The  in our SDE.
  
  Returns:
    The vector of diffusion coefficients.
  """
  return sigma**t

sigma =  25.0# @param {'type':'number'}

# %%
# sampling
min_signal_rate = 0.02
max_signal_rate = 0.95

def diffusion_schedule(diffusion_times):
    # diffusion times -> angles
    start_angle = tf.acos(max_signal_rate)
    end_angle = tf.acos(min_signal_rate)

    diffusion_angles = start_angle + diffusion_times * (end_angle - start_angle)

    # angles -> signal and noise rates
    signal_rates = tf.cos(diffusion_angles)
    noise_rates = tf.sin(diffusion_angles)
    # note that their squared sum is always: sin^2(x) + cos^2(x) = 1

    return noise_rates, signal_rates

# %%
t = np.linspace(0, 1, num=50)

# %%
noise_rates, signal_rates = diffusion_schedule(t)

# %%
noise_rates
# Out:
# <tf.Tensor: shape=(50,), dtype=float32, numpy=
# array([0.3122499 , 0.33605814, 0.3596535 , 0.3830211 , 0.40614605,
#        0.42901376, 0.45160976, 0.4739197 , 0.49592942, 0.51762503,
#        0.5389928 , 0.5600192 , 0.58069086, 0.60099477, 0.6209179 ,
#        0.64044785, 0.65957206, 0.67827857, 0.6965554 , 0.71439105,
#        0.7317742 , 0.7486939 , 0.7651392 , 0.7811001 , 0.7965661 ,
#        0.8115276 , 0.82597506, 0.8398994 , 0.85329175, 0.8661436 ,
#        0.8784468 , 0.89019364, 0.9013766 , 0.9119887 , 0.9220231 ,
#        0.9314735 , 0.9403339 , 0.9485987 , 0.95626265, 0.9633209 ,
#        0.96976906, 0.97560287, 0.9808188 , 0.98541343, 0.98938394,
#        0.99272776, 0.9954428 , 0.99752736, 0.99898005, 0.99979997],
#       dtype=float32)>

# %%
sqrt_alpha = signal_rates
sqrt_1_minus_alpha = noise_rates
alpha = signal_rates**2
r_1_minus_alpha = noise_rates**2
one = alpha + r_1_minus_alpha

# %%
plt.plot(t, sqrt_alpha, label="noise_signal sqrt(1-alpha)")
plt.plot(t, sqrt_1_minus_alpha, label="signal_rates sqrt(alpha)")
#plt.plot(t, 1 - signal_rates, label="1-signal_rates (1 - alpha)")
plt.legend()

# %%
plt.plot(t, alpha, label="alpha")
plt.plot(t, r_1_minus_alpha, label="1 - alpha")
plt.plot(t, one, label="alpha + 1 - alpha")
plt.legend()

# %%
betas_test= []
prev_alpha = 0
curr_alpha = alpha[len(alpha) - 1]
betas_test.append(1 -(prev_alpha / curr_alpha))
for i in range(len(alpha) - 1):
    prev_alpha = alpha[len(alpha) - (i+1)]
    curr_alpha = alpha[len(alpha) - (i+2)]
    betas_test.append(1 -(prev_alpha / curr_alpha))

plt.scatter(t, betas_test)
plt.scatter(t, np.flip(alpha))
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
eps=1e-3
num_steps=350
time_steps = 1 - np.linspace(1, eps, num_steps)

noise_rates, signal_rates = diffusion_schedule(time_steps)
alpha = signal_rates**2

betas_test= []
prev_alpha = 0
curr_alpha = alpha[len(alpha) - 1]
betas_test.append(1 -(prev_alpha / curr_alpha))
for i in range(len(alpha) - 1):
    prev_alpha = alpha[len(alpha) - (i+1)]
    curr_alpha = alpha[len(alpha) - (i+2)]
    betas_test.append(1 -(prev_alpha / curr_alpha))

plt.scatter(time_steps, betas_test)
plt.scatter(time_steps, np.flip(alpha))
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
len(alpha)
# Out:
# 50

# %%
# SentencePiece tokenizer := V_size = 32000
# We L2-normalise the embeddings and scale them by sqrt(d)

# %%
img_embed_size = 24
categories_nb = 4

# %%
# data
num_epochs = 50  # train for at least 50 epochs for good results
image_size = (64, 128)

plot_diffusion_steps = 20

# architecture
widths = [64, 128, 256, 512]
block_depth = 2

# optimization
batch_size = 60
ema = 0.999
learning_rate = 1e-5
weight_decay = 1e-4

# %%
# Useful constants
slice_size = (64, 128)
cmap, norm = get_color_map(number_of_categories=4)
facies_names = np.array(["Sand, Channel lag", "Sand, Point bar", "Silts, Levee", "Shale, Overbank"])

# %%
x = load_data(slice_size[0], slice_size[1], "./data/horizontal/dataFlumyHoriz.csv")

# %%
print(x.shape)
# Out:
# (3000, 64, 128, 4)

# %%
x_train = x[:2760]

# %%
print(x_train.shape)
# Out:
# (2760, 64, 128, 4)

# %%
x_test = x[2760:]

# %%
print(x_test.shape)
# Out:
# (240, 64, 128, 4)

# %%
class GaussianFourierProjection(tf.keras.layers.Layer):
    """Gaussian random features for encoding time steps."""  
    def __init__(self, embed_dim, scale=30.):
        super().__init__()
        # Randomly sample weights during initialization. These weights are fixed 
        # during optimization and are not trainable.
        self.W = self.add_weight(shape=(embed_dim // 2,),
                                 trainable=False,
                                 initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=1.), name="GFP") * tf.constant(scale, dtype=tf.float32)
    
    @tf.function
    def call(self, x):
        x_proj = x * self.W * tf.constant(2., dtype=tf.float32) * tf.constant(np.pi, dtype=tf.float32)
        y = tf.concat([tf.math.sin(x_proj), tf.cos(x_proj)], axis=-1)
        return y # Probleme vient pas de là :()

class CustomLinear(tf.keras.layers.Layer):
    """Rhaaah."""  
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.W = tf.random.uniform((input_dim, output_dim), minval=-tf.math.sqrt(1/input_dim), maxval=tf.math.sqrt(1/input_dim))
        self.b = tf.random.uniform((1, output_dim, ), minval=-tf.math.sqrt(1/input_dim), maxval=tf.math.sqrt(1/input_dim))
    
    @tf.function
    def call(self, x):
        y = tf.tensordot(x, self.W, 1) + self.b
        y = tf.keras.activations.gelu(y)

        return y

@tf.function
def embedding_normalization(logits):
    # normalement vont avoir taille (batch_size, sequence_size, embedding_size)
    # axis=-1 is embedding normalement
    return (logits / tf.norm(logits, axis=-1, keepdims=True)) * tf.constant(np.sqrt(logits.shape[-1]), dtype=tf.float32)

class NormalizedEmbedding(tf.keras.layers.Layer):
    """"""  
    def __init__(self, categories_nb, img_embed_size):
        super().__init__()
        self.embed_layer = tf.keras.layers.Embedding(categories_nb, img_embed_size)
        self.embed_layer2 = layers.Conv2D(img_embed_size, kernel_size=3, padding="same", activation=keras.activations.swish)
        self.embed_layer3 = layers.Conv2D(img_embed_size, kernel_size=3, padding="same", activation=keras.activations.swish)
        self.embed_layer4 = layers.Conv2D(img_embed_size, kernel_size=1, activation=None) #layers.Dense(img_embed_size, activation=keras.activations.swish)
    
    @tf.function
    def call(self, x):
        y = self.embed_layer(x)
        y = self.embed_layer2(y)
        y = self.embed_layer3(y)
        y = self.embed_layer4(y)
        y = embedding_normalization(y)

        return y

# %%
def ResidualBlock(width):
    def apply(x):
        input_width = x.shape[3]
        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(width, kernel_size=1)(x)
        if x.shape[-1] % 32 != 0:
            x = tfa.layers.GroupNormalization(input_width // 4, epsilon=1e-05)(x)
        else : 
            x = tfa.layers.GroupNormalization(32, epsilon=1e-05)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", activation=keras.activations.swish
        )(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same")(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownBlock(width, block_depth):
    def apply(x):
        x, skips = x
        for _ in range(block_depth):
            x = ResidualBlock(width)(x)
            skips.append(x)
        x = layers.AveragePooling2D(pool_size=2)(x)
        return x

    return apply


def UpBlock(width, block_depth):
    def apply(x):
        x, skips = x
        x = layers.UpSampling2D(size=2, interpolation="bilinear")(x)
        for _ in range(block_depth):
            x = layers.Concatenate()([x, skips.pop()])
            x = ResidualBlock(width)(x)
        return x

    return apply

# %%
def get_network(image_size, widths, block_depth, img_embed_size=16, t_embed_dim=16):
    noisy_images = keras.Input(shape=(image_size[0], image_size[1], img_embed_size))
    diffusion_times = keras.Input(shape=(1, 1, 1))

    time_embed = GaussianFourierProjection(embed_dim=t_embed_dim)(diffusion_times)
    time_embed = CustomLinear(t_embed_dim, t_embed_dim)(time_embed)
    time_embed = CustomLinear(t_embed_dim, t_embed_dim)(time_embed)
    time_embed =  time_embed * tf.math.sigmoid(time_embed)
    time_embed = layers.UpSampling2D(size=image_size, interpolation="nearest")(time_embed)

    x = layers.Conv2D(widths[0], kernel_size=1)(noisy_images)
    x = layers.Concatenate(axis=-1)([x, time_embed])

    skips = []
    for width in widths[:-1]:
        x = DownBlock(width, block_depth)([x, skips])

    for _ in range(block_depth):
        x = ResidualBlock(widths[-1])(x)

    for width in reversed(widths[:-1]):
        x = UpBlock(width, block_depth)([x, skips])

    x = layers.Conv2D(4, kernel_size=1, kernel_initializer="zeros", activation="softmax")(x)

    return keras.Model([noisy_images, diffusion_times], x, name="residual_unet")

# %%
norm_groups = 8  # Number of groups used in GroupNormalization layer

img_size = 64
img_channels = 3
clip_min = -1.0
clip_max = 1.0

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2  # Number of residual blocks

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


class TimeEmbedding(layers.Layer):
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        return emb


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(
                width, kernel_size=1, kernel_initializer=kernel_init(1.0)
            )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, kernel_initializer=kernel_init(1.0))(temb)[
            :, None, None, :
        ]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(0.0)
        )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(
            width,
            kernel_size=3,
            strides=2,
            padding="same",
            kernel_initializer=kernel_init(1.0),
        )(x)
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0)
        )(x)
        return x

    return apply


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(
            units, activation=activation_fn, kernel_initializer=kernel_init(1.0)
        )(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply


def build_model(
    img_size,
    img_channels,
    widths,
    has_attention,
    num_res_blocks=2,
    norm_groups=8,
    t_embed_dim=32,
    interpolation="nearest",
    activation_fn=keras.activations.swish,
):
    image_input = layers.Input(
        shape=(image_size[0], image_size[1], img_channels), name="image_input"
    )
    time_input = keras.Input(shape=(1, 1, 1), name="time_input")

    x = layers.Conv2D(
        first_conv_channels,
        kernel_size=(3, 3),
        padding="same",
        kernel_initializer=kernel_init(1.0),
    )(image_input)

    time_embed = GaussianFourierProjection(embed_dim=t_embed_dim)(time_input)
    time_embed = CustomLinear(t_embed_dim, t_embed_dim)(time_embed)
    time_embed =  time_embed * tf.math.sigmoid(time_embed)
    time_embed = tf.squeeze(time_embed, axis=[1, 2])

    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, time_embed])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, time_embed]
    )
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)(
        [x, time_embed]
    )

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(
                widths[i], groups=norm_groups, activation_fn=activation_fn
            )([x, time_embed])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(4, (3, 3), padding="same", kernel_initializer=kernel_init(0.0), activation="softmax")(x)
    return keras.Model([image_input, time_input], x, name="unet")

# %%
batch_size = 30

# %%
class DiffusionModel(keras.Model):
    def __init__(self, image_size, widths, block_depth, img_embed_size, categories_nb):
        super().__init__()

        #self.normalizer = layers.Normalization()
        self.network = build_model(image_size, img_embed_size, widths, has_attention=[False, False, True, True]) #get_network(image_size, widths, block_depth, img_embed_size=img_embed_size, t_embed_dim=img_embed_size)
        self.img_embed_size = img_embed_size
        self.ema_network = keras.models.clone_model(self.network)
        self.embedding_layer = NormalizedEmbedding(categories_nb, img_embed_size)
        self.emb_optimiser = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)

    def compile(self, **kwargs):
        super().compile(**kwargs)

        self.noise_loss_tracker = keras.metrics.Mean(name="n_loss")
        self.image_loss_tracker = keras.metrics.Mean(name="i_loss")
        #self.kid = KID(name="kid")

    @property
    def metrics(self):
        return [self.noise_loss_tracker, self.image_loss_tracker]

    def denoise(self, noisy_images, diffusion_times, training):
        # the exponential moving average weights are used at evaluation
        if training:
            network = self.network
        else:
            network = self.ema_network

        # predict noise component and calculate the image component using it
        pred_images = self.network([noisy_images, diffusion_times], training=training)

        return pred_images

    def train_step(self, images, eps=1e-5, sigma=25.):
        # batch_size = images.shape[0]
        noises = tf.random.normal(shape=(batch_size, image_size[0], image_size[1], self.img_embed_size))

        # sample uniform random diffusion times
        diffusion_times = tf.random.uniform(
            shape=(batch_size, 1, 1, 1), minval=0.0, maxval=1.0
        ) #* tf.constant((1. - eps), dtype=tf.float32) + tf.constant(eps, dtype=tf.float32)

        int_encoded_img = tf.argmax(images, axis=-1)

        with tf.GradientTape() as tape1, tf.GradientTape() as tape2:
            embed_images = self.embedding_layer(int_encoded_img)
            noise_rates, signal_rates = diffusion_schedule(diffusion_times)
            noisy_images = signal_rates * embed_images + noise_rates * noises

            # train the network to separate noisy images to their components
            pred_images = self.denoise(
                noisy_images, diffusion_times, training=True
            )

            image_loss = self.loss(images, pred_images)  # training loss
            

        gradients_model = tape1.gradient(image_loss, self.network.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients_model, self.network.trainable_weights))

        gradients_embeddings = tape2.gradient(image_loss, self.embedding_layer.trainable_weights)
        self.emb_optimiser.apply_gradients(zip(gradients_embeddings, self.embedding_layer.trainable_weights))

        self.noise_loss_tracker.update_state(image_loss)
        self.image_loss_tracker.update_state(image_loss)

        return {m.name: m.result() for m in self.metrics[:-1]}

    def test_step(self, images, eps=1e-5, sigma=25.):

        if isinstance(images, tuple):
            images = images[0]

        # batch_size = 60 images.shape[0]
        noises = tf.random.normal(shape=(images.shape[0], image_size[0], image_size[1], self.img_embed_size))

        # sample uniform random diffusion times
        diffusion_times = tf.random.uniform(
            shape=(images.shape[0], 1, 1, 1), minval=0.0, maxval=1.0
        ) #* tf.constant((1. - eps) + eps, dtype=tf.float32)

        int_encoded_img = tf.argmax(images, axis=-1)

        embed_images = self.embedding_layer(int_encoded_img)

        #std = marginal_prob_std(diffusion_times, sigma=sigma)
        noise_rates, signal_rates = diffusion_schedule(diffusion_times)
        noisy_images = signal_rates * embed_images + noise_rates * noises
        #noisy_images = embed_images + noises * tf.reshape(std, (-1, 1, 1, 1))

        # use the network to separate noisy images to their components
        pred_images = self.denoise(
            noisy_images, diffusion_times, training=False
        )

        image_loss = self.loss(images, pred_images)

        self.image_loss_tracker.update_state(image_loss)
        self.noise_loss_tracker.update_state(image_loss)


        return {m.name: m.result() for m in self.metrics}

# %%
# create and compile the model
model = DiffusionModel(image_size, widths, block_depth, img_embed_size=img_embed_size, categories_nb=categories_nb)

learning_rate = 1e-4

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=learning_rate,
    ),
    loss= tf.keras.losses.CategoricalCrossentropy(),
)

# run training and plot generated images periodically

# %%
history = model.fit(x_train, batch_size=batch_size, epochs=200, validation_data=(x_test,))
# Out:
# Epoch 1/200
# 92/92 [==============================] - 133s 1s/step - n_loss: 0.1315 - val_n_loss: 0.1177 - val_i_loss: 0.1177
# Epoch 2/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.1150 - val_n_loss: 0.0997 - val_i_loss: 0.0997
# Epoch 3/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.1060 - val_n_loss: 0.1062 - val_i_loss: 0.1062
# Epoch 4/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.1040 - val_n_loss: 0.1132 - val_i_loss: 0.1132
# Epoch 5/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0954 - val_n_loss: 0.0913 - val_i_loss: 0.0913
# Epoch 6/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0961 - val_n_loss: 0.0916 - val_i_loss: 0.0916
# Epoch 7/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0851 - val_n_loss: 0.0632 - val_i_loss: 0.0632
# Epoch 8/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0930 - val_n_loss: 0.0827 - val_i_loss: 0.0827
# Epoch 9/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0886 - val_n_loss: 0.0806 - val_i_loss: 0.0806
# Epoch 10/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0816 - val_n_loss: 0.0714 - val_i_loss: 0.0714
# Epoch 11/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0806 - val_n_loss: 0.0887 - val_i_loss: 0.0887
# Epoch 12/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0804 - val_n_loss: 0.0708 - val_i_loss: 0.0708
# Epoch 13/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0783 - val_n_loss: 0.0807 - val_i_loss: 0.0807
# Epoch 14/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0763 - val_n_loss: 0.0696 - val_i_loss: 0.0696
# Epoch 15/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0769 - val_n_loss: 0.0534 - val_i_loss: 0.0534
# Epoch 16/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0756 - val_n_loss: 0.0776 - val_i_loss: 0.0776
# Epoch 17/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0841 - val_n_loss: 0.0665 - val_i_loss: 0.0665
# Epoch 18/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0763 - val_n_loss: 0.0673 - val_i_loss: 0.0673
# Epoch 19/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0787 - val_n_loss: 0.0614 - val_i_loss: 0.0614
# Epoch 20/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0707 - val_n_loss: 0.0703 - val_i_loss: 0.0703
# Epoch 21/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0751 - val_n_loss: 0.0751 - val_i_loss: 0.0751
# Epoch 22/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0739 - val_n_loss: 0.0816 - val_i_loss: 0.0816
# Epoch 23/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0701 - val_n_loss: 0.0785 - val_i_loss: 0.0785
# Epoch 24/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0674 - val_n_loss: 0.0688 - val_i_loss: 0.0688
# Epoch 25/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0655 - val_n_loss: 0.0704 - val_i_loss: 0.0704
# Epoch 26/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0741 - val_n_loss: 0.0706 - val_i_loss: 0.0706
# Epoch 27/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0742 - val_n_loss: 0.0644 - val_i_loss: 0.0644
# Epoch 28/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0694 - val_n_loss: 0.0708 - val_i_loss: 0.0708
# Epoch 29/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0660 - val_n_loss: 0.0690 - val_i_loss: 0.0690
# Epoch 30/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0706 - val_n_loss: 0.0648 - val_i_loss: 0.0648
# Epoch 31/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0743 - val_n_loss: 0.0692 - val_i_loss: 0.0692
# Epoch 32/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0712 - val_n_loss: 0.0687 - val_i_loss: 0.0687
# Epoch 33/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0665 - val_n_loss: 0.0697 - val_i_loss: 0.0697
# Epoch 34/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0680 - val_n_loss: 0.0503 - val_i_loss: 0.0503
# Epoch 35/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0677 - val_n_loss: 0.0678 - val_i_loss: 0.0678
# Epoch 36/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0699 - val_n_loss: 0.0700 - val_i_loss: 0.0700
# Epoch 37/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0683 - val_n_loss: 0.0814 - val_i_loss: 0.0814
# Epoch 38/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0672 - val_n_loss: 0.0693 - val_i_loss: 0.0693
# Epoch 39/200
# 92/92 [==============================] - 131s 1s/step - n_loss: 0.0663 - val_n_loss: 0.0675 - val_i_loss: 0.0675
# Epoch 40/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0637 - val_n_loss: 0.0632 - val_i_loss: 0.0632
# Epoch 41/200
# 92/92 [==============================] - 132s 1s/step - n_loss: 0.0698 - val_n_loss: 0.0801 - val_i_loss: 0.0801
# Epoch 42/200
# 14/92 [===>..........................] - ETA: 1:47 - n_loss: 0.0713
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-db11e7304354> in <cell line: 1>()
# ----> 1 history = model.fit(x_train, batch_size=batch_size, epochs=200, validation_data=(x_test,))
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1689                             logs = tmp_logs
#    1690                             end_step = step + data_handler.step_increment
# -> 1691                             callbacks.on_train_batch_end(end_step, logs)
#    1692                             if self.stop_training:
#    1693                                 break
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.9/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     678         return t.item() if np.ndim(t) == 0 else t
#     679
# --> 680     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     681
#     682
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     671         # Don't turn ragged or sparse tensors to NumPy.
#     672         if isinstance(t, tf.Tensor):
# --> 673             t = t.numpy()
#     674         # Strings, ragged and sparse tensors don't have .item(). Return them
#     675         # as-is.
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1158     """
#    1159     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1162
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1124   def _numpy(self):
#    1125     try:
# -> 1126       return self._numpy_internal()
#    1127     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1128       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
eps=1e-5

images = x_train[:batch_size]

noises = tf.random.normal(shape=(images.shape[0], image_size[0], image_size[1], model.img_embed_size))

# sample uniform random diffusion times
diffusion_times = tf.random.uniform(
    shape=(images.shape[0], 1, 1, 1), minval=0.95, maxval=0.99
) * tf.constant((1. - eps) + eps, dtype=tf.float32)

int_encoded_img = tf.argmax(images, axis=-1)

embed_images = model.embedding_layer(int_encoded_img)

#std = marginal_prob_std(diffusion_times, sigma=sigma)
noise_rates, signal_rates = diffusion_schedule(diffusion_times)
noisy_images = signal_rates * embed_images + noise_rates * noises
#noisy_images = embed_images + noises * tf.reshape(std, (-1, 1, 1, 1))

# use the network to separate noisy images to their components
pred_images = model.denoise(noisy_images, diffusion_times, training=False)

for i in range(batch_size):
    plt.figure(figsize=(10, 5))
    plt.title("Timestep {0:.3f}".format(diffusion_times[i, 0, 0, 0]))
    plt.axis('off')

    plt.imshow(np.argmax(pred_images[i].numpy(), axis=-1).reshape((64, 128)),
                interpolation='nearest', cmap=cmap, norm=norm)
    plt.show()

# %%
x_axis = np.arange(50)
plt.figure(figsize=(10, 5))
plt.plot(x_axis, history.history["n_loss"], label="Training image CE loss")
plt.plot(x_axis, history.history["val_n_loss"], label="Testing image CE loss")
plt.legend(loc="upper left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-f101a510253e> in <cell line: 3>()
#       1 x_axis = np.arange(50)
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.plot(x_axis, history.history["n_loss"], label="Training image CE loss")
#       4 plt.plot(x_axis, history.history["val_n_loss"], label="Testing image CE loss")
#       5 plt.legend(loc="upper left")
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (1,)

# %%
import tqdm

def compute_beta(curr_alphas, prev_alphas):
    #curr_alphas = diffusion_schedule(current_t)**2
    #prev_alphas = diffusion_schedule(previous_t)**2 # + 1e-12

    print("BETASCOMPUTE")
    print(curr_alphas[0], prev_alphas[0])
    print((prev_alphas / curr_alphas)[0])
    betas = 1 - (prev_alphas / curr_alphas)
    print("BETASCOMPUTE")
    return betas

def score_model(x, t, curr_1_minus_alphas):
    pred_x0 = model.denoise(x, t, training=False)
    int_encoded_img = tf.argmax(pred_x0, axis=-1)
    embed_pred_x0 = model.embedding_layer(int_encoded_img)

    return (embed_pred_x0 - x) / curr_1_minus_alphas #**2

# %%
x_test.shape
# Out:
# (240, 64, 128, 4)

# %%
# There is something rotten in my sampling code :(
# Clairement le calcul du beta

# %%
print(betas_test)
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=1.0
=float32, numpy=0.040391505>, <tf.Tensor: shape=(), dtype=float32, numpy=0.03957826>, <tf.Tensor: shape=(), dtype=float32, numpy=0.03880918>, <tf.Tensor: shape=(), dtype=float32, numpy=0.038082182>, <tf.Tensor: shape=(), dtype=float32, numpy=0.03735739>, <tf.Tensor: shape=(), dtype=float32, numpy=0.03667748>, <tf.Tensor: shape=(), dtype=float32, numpy=0.036016166>, <tf.Tensor: shape=(), dtype=float32, numpy=0.035372198>, <tf.Tensor: shape=(), dtype=float32, numpy=0.034762383>, <tf.Tensor: shape=(), dtype=float32, numpy=0.03416747>, <tf.Tensor: shape=(), dtype=float32, numpy=0.0335927>, <tf.Tensor: shape=(), dtype=float32, numpy=0.033031583>, <tf.Tensor: shape=(), dtype=float32, numpy=0.032499135>, <tf.Tensor: shape=(), dtype=float32, numpy=0.031978607>, <tf.Tensor: shape=(), dtype=float32, numpy=0.031469107>, <tf.Tensor: shape=(), dtype=float32, numpy=0.030985832>, <tf.Tensor: shape=(), dtype=float32, numpy=0.030512214>, <tf.Tensor: shape=(), dtype=float32, numpy=0.030052662>, <tf.Tensor: shape=(), dtype=float32, numpy=0.029606879>, <tf.Tensor: shape=(), dtype=float32, numpy=0.029169261>, <tf.Tensor: shape=(), dtype=float32, numpy=0.028753757>, <tf.Tensor: shape=(), dtype=float32, numpy=0.028345108>, <tf.Tensor: shape=(), dtype=float32, numpy=0.027948081>, <tf.Tensor: shape=(), dtype=float32, numpy=0.027557552>, <tf. ...

# %% [markdown]
# TESTS

# %%
import tqdm

def pc_sampler(score_model,
               img_embed_size,
               batch_size=64, 
               num_steps=300,
               signal_to_noise_ratio=0.16,
               sigma=25.,
               eps=1e-3):
    t = tf.ones((batch_size, 1, 1, 1), dtype=tf.float32)
    #std = marginal_prob_std(t, sigma)
    noise_rates, signal_rates = diffusion_schedule(t)
    #print("STD ", std)
    # Create initial noise ?

    init_x = tf.random.uniform((batch_size, 64, 128), 0, 4, dtype=tf.dtypes.int32) #* tf.reshape(std, (-1, 1, 1, 1))
    #print(init_x.shape)
    samples_list = []
    samples_list.append( tf.keras.backend.constant(keras.utils.to_categorical(init_x)))
    noises = tf.random.normal(shape=(batch_size, image_size[0], image_size[1], img_embed_size))
    init_x = noises
    #init_x = model.embedding_layer(init_x) + noises * tf.reshape(std, (-1, 1, 1, 1))

    time_steps = tf.linspace(1., eps, num_steps)
    step_size = time_steps[0] - time_steps[1]
    x = init_x
    prev_alphas = signal_rates**2
    for time_step in tqdm.notebook.tqdm(time_steps):
        batch_time_step = tf.ones((batch_size, 1, 1, 1), dtype=tf.float32) * time_step
        noise_rates, signal_rates = diffusion_schedule(batch_time_step)
        cur_alphas = signal_rates**2
        betas = compute_beta(cur_alphas, prev_alphas)

        # CORRECTOR STEP
        #std = marginal_prob_std(batch_time_step, sigma)
        grad = score_model(x, batch_time_step, cur_alphas) 
        grad_norm = tf.math.reduce_mean(tf.norm(tf.reshape(grad, (grad.shape[0], -1)), axis=-1))
        noise_norm = np.sqrt(np.prod(x.shape[1:]))
        langevin_step_size = 2 * cur_alphas * (signal_to_noise_ratio * noise_norm / grad_norm)**2
        x = x + langevin_step_size * grad + tf.math.sqrt(2 * langevin_step_size) * tf.random.normal(x.shape)
        
        # PREDICTOR STEP
        #g = diffusion_coeff(batch_time_step, sigma=sigma)
        mean_x = (2 - tf.sqrt(1 - betas)) * x + tf.reshape(betas, (-1, 1, 1, 1)) * score_model(x, batch_time_step, cur_alphas) #* step_size
        x = mean_x + tf.reshape(tf.math.sqrt(betas), (-1, 1, 1, 1)) * tf.random.normal(x.shape)
        samples_post = model.denoise(mean_x, batch_time_step, training=False)
        samples_list.append(samples_post)
        prev_alphas = cur_alphas

    return samples_post, samples_list

# %%
#@title Sampling (double click to expand or collapse)

from torchvision.utils import make_grid

## Load the pre-trained checkpoint from disk.

sample_batch_size = 10 #@param {'type':'integer'}
sampler = pc_sampler #@param ['Euler_Maruyama_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
samples, samples_list = sampler(score_model,
                                img_embed_size,
                                sample_batch_size,)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# BETASCOMPUTE
# tf.Tensor([[[1.9106855e-15]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[1.9106855e-15]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[1.]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[2.280276e-05]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[1.9106855e-15]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[8.379185e-11]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[9.1212074e-05]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[2.280276e-05]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.24999717]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00020522]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[9.1212074e-05]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.4444636]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00036482]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00020522]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.56252444]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00056998]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00036482]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.64004636]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00082071]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00056998]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.69449866]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00111697]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00082071]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.7347688]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00145874]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00111697]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.76570934]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00184597]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00145874]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.79022753]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00227866]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00184597]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.81011456]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00275673]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00227866]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.82658005]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00328017]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00275673]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.8404227]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.0038489]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00328017]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.8522346]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00446291]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.0038489]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.86242014]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.0051221]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00446291]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.8713044]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00582645]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.0051221]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.87911206]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00657585]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00582645]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.88603675]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00737029]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00657585]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.8922113]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00820963]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00737029]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.8977606]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.00909386]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00820963]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9027665]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01002284]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.00909386]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9073134]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01099654]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01002284]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.91145396]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01201482]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01099654]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9152481]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01307764]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01201482]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.91873026]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01418484]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01307764]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9219445]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01533639]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01418484]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.92491406]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01653212]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01533639]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9276726]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01777198]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01653212]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9302351]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.01905578]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01777198]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.932629]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02038346]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.01905578]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.93486494]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02175492]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02038346]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.93695855]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02316997]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02175492]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9389274]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02462855]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02316997]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9407769]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02613045]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02462855]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.942523]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02767562]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02613045]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9441686]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.02926383]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02767562]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.94572794]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03089502]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.02926383]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9472022]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03256895]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03089502]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.94860333]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03428556]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03256895]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9499321]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03604462]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03428556]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.95119774]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03784603]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03604462]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9524015]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.03968956]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03784603]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9535514]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.04157512]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.03968956]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.95464677]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.04350245]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.04157512]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9556962]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.04547146]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.04350245]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.95669776]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.04748189]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.04547146]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9576591]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.04953364]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.04748189]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9585786]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.05162643]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.04953364]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9594628]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.05376017]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.05162643]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96031004]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.05593456]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.05376017]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9611262]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.05814951]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.05593456]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96190935]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.06040471]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.05814951]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96266514]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.06270008]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.06040471]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9633913]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.06503525]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.06270008]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9640937]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.06741018]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.06503525]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96476907]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.06982449]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.06741018]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96542317]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.07227811]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.06982449]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.966053]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.07477067]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.07227811]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9666639]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.07730209]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.07477067]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9672529]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.079872]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.07730209]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9678247]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.0824803]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.079872]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96837664]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.08512662]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.0824803]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96891314]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.08781085]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.08512662]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9694317]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.0905326]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.08781085]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.96993625]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.09329177]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.0905326]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0
]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.8835086]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.88042724]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99651235]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.88655514]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.8835086]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9965637]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.8895663]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.88655514]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.996615]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.892542]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.8895663]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.996666]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.8954818]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.892542]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99671704]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.8983856]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.8954818]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9967678]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9012531]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.8983856]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9968183]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.90408385]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9012531]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9968689]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9068778]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.90408385]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99691916]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.90963477]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9068778]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99696916]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.91235423]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.90963477]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9970193]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.91503614]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.91235423]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99706906]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9176802]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.91503614]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9971188]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.92028606]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9176802]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9971684]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9228536]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.92028606]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99721783]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9253827]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9228536]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.997267]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.92787296]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9253827]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9973161]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9303241]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.92787296]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9973653]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.932736]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9303241]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9974142]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9351085]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.932736]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99746287]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9374413]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9351085]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9975115]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9397341]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9374413]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99756014]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9419869]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9397341]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9976084]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9441994]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9419869]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99765676]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.94637126]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9441994]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99770504]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9485026]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.94637126]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99775296]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9505928]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9485026]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9978011]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.952642]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9505928]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9978489]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.95465]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.952642]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9978967]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9566164]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.95465]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9979444]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.95854115]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9566164]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.997992]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9604242]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.95854115]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99803936]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.96226513]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9604242]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99808687]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.964064]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.96226513]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9981341]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9658205]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.964064]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99818134]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.96753436]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9658205]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9982286]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.96920586]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.96753436]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9982754]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9708344]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.96920586]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99832255]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9724199]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9708344]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9983695]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9739624]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9724199]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99841624]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9754618]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9739624]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9984629]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9769176]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9754618]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99850976]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9783301]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9769176]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.99855626]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE
# BETASCOMPUTE
# tf.Tensor([[[0.9796988]]], shape=(1, 1, 1), dtype=float32) tf.Tensor([[[0.9783301]]], shape=(1, 1, 1), dtype=float32)
# tf.Tensor([[[0.9986029]]], shape=(1, 1, 1), dtype=float32)
# BETASCOMPUTE

# %%
samples.shape
# Out:
# TensorShape([10, 64, 128, 4])

# %%
plt.figure(figsize=(10, 5))
plt.axis('off')

plt.imshow(np.argmax(samples[0].numpy(), axis=-1).reshape((64, 128)),
            interpolation='nearest', cmap=cmap, norm=norm)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.axis('off')

plt.imshow(np.argmax(samples[9].numpy(), axis=-1).reshape((64, 128)),
            interpolation='nearest', cmap=cmap, norm=norm)
plt.show()

# %%
import imageio
images = []
for i, batch in enumerate(samples_list):
    figure = plt.figure(figsize=(10, 5))
    plt.axis('off')
    plt.title("Timestep {0:.3f}".format(1 - (i / 350)))
    plt.imshow(np.argmax(batch[0].numpy(), axis=-1).reshape((64, 128)),
                interpolation='nearest', cmap=cmap, norm=norm)
    plt.savefig('foo.png', bbox_inches='tight')
    images.append(imageio.imread('foo.png'))
    plt.show() #close(figure)
imageio.mimsave('/movie.gif', images)
# Out:
# <ipython-input-209-76020cfbaf4c>:10: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread('foo.png'))

# %%
plt.figure(figsize=(10, 5))
plt.axis('off')

plt.imshow(np.argmax(samples[2].numpy(), axis=-1).reshape((64, 128)),
            interpolation='nearest', cmap=cmap, norm=norm)
plt.show()

# %%
import numpy as np

def show_images(array_img, cmap, norm):
    # IMAGES
    plt.figure(figsize=(10, 5))
    plt.axis('off')
    slice_h = array_img.numpy().shape[1]
    slice_w = array_img.numpy().shape[2]
  

    size_high_res = (slice_h, slice_w)

    plt.imshow(np.argmax(array_img.numpy(), axis=-1).reshape(size_high_res),
               interpolation='nearest', cmap=cmap, norm=norm)
    plt.show()
